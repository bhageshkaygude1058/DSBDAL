# %%
import pandas as pd

# %%
data = [
    ["Jon", 25, "Seattle"],
    ["Robb", 30, "New York"],
    ["Danerys", 35, "Kona"]
]

df_list = pd.DataFrame(
    data,
    columns=["Name", "Age", "Location"],
    index=[1, 2, 3]
)

df_list
# Out:
#       Name  Age  Location
# 1      Jon   25   Seattle
# 2     Robb   30  New York
# 3  Danerys   35      Kona

# %%
df_list.head()
# Out:
#       Name  Age  Location
# 1      Jon   25   Seattle
# 2     Robb   30  New York
# 3  Danerys   35      Kona

# %%
df_list.tail()
# Out:
#       Name  Age  Location
# 1      Jon   25   Seattle
# 2     Robb   30  New York
# 3  Danerys   35      Kona

# %%
df_list.shape
# Out:
# (3, 3)

# %%
df_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, 1 to 3
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      3 non-null      object
#  1   Age       3 non-null      int64
#  2   Location  3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 96.0+ bytes

# %%
df_list.describe()
# Out:
#         Age
# count   3.0
# mean   30.0
# std     5.0
# min    25.0
# 25%    27.5
# 50%    30.0
# 75%    32.5
# max    35.0

# %%
df_list["Age"].max()
# Out:
# 35

# %%
df_list["Age"].min()
# Out:
# 25

# %%
df_list["Age"].mean()
# Out:
# np.float64(30.0)

# %%
df_list.loc[1]
# Out:
# Name            Jon
# Age              25
# Location    Seattle
# Name: 1, dtype: object

# %%
df_list.drop(3)
# Out:
#    Name  Age  Location
# 1   Jon   25   Seattle
# 2  Robb   30  New York

# %%
df_list.isnull()
# Out:
#     Name    Age  Location
# 1  False  False     False
# 2  False  False     False
# 3  False  False     False

# %%
data = (
    ("Jon", 25, "Seattle"),
    ("Robb", 30, "New York"),
    ("Danerys", 35, "Kona")
)

df_tuple = pd.DataFrame(
    data,
    columns=["Name", "Age", "Location"],
    index=[1, 2, 3]
)

df_tuple
# Out:
#       Name  Age  Location
# 1      Jon   25   Seattle
# 2     Robb   30  New York
# 3  Danerys   35      Kona

# %%
df_tuple.head()
# Out:
#       Name  Age  Location
# 1      Jon   25   Seattle
# 2     Robb   30  New York
# 3  Danerys   35      Kona

# %%
df_tuple.tail()
# Out:
#       Name  Age  Location
# 1      Jon   25   Seattle
# 2     Robb   30  New York
# 3  Danerys   35      Kona

# %%
df_tuple.shape
# Out:
# (3, 3)

# %%
df_tuple.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, 1 to 3
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      3 non-null      object
#  1   Age       3 non-null      int64
#  2   Location  3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 96.0+ bytes

# %%
df_tuple.describe()
# Out:
#         Age
# count   3.0
# mean   30.0
# std     5.0
# min    25.0
# 25%    27.5
# 50%    30.0
# 75%    32.5
# max    35.0

# %%
df_tuple["Age"].max()
# Out:
# 35

# %%
df_tuple["Age"].min()
# Out:
# 25

# %%
df_tuple["Age"].mean()
# Out:
# np.float64(30.0)

# %%
df_tuple.loc[1]
# Out:
# Name            Jon
# Age              25
# Location    Seattle
# Name: 1, dtype: object

# %%
df_tuple.iloc[0:]
# Out:
#       Name  Age  Location
# 1      Jon   25   Seattle
# 2     Robb   30  New York
# 3  Danerys   35      Kona

# %%
data = {
    "Name": ["Jon", "Robb", "Danerys"],
    "Age": [25, 30, 35],
    "Location": ["Seattle", "New York", "Kona"]
}

df_dict = pd.DataFrame(data, index=[1, 2, 3])

df_dict
# Out:
#       Name  Age  Location
# 1      Jon   25   Seattle
# 2     Robb   30  New York
# 3  Danerys   35      Kona

# %%
df_dict.head()
# Out:
#       Name  Age  Location
# 1      Jon   25   Seattle
# 2     Robb   30  New York
# 3  Danerys   35      Kona

# %%
df_dict.tail()
# Out:
#       Name  Age  Location
# 1      Jon   25   Seattle
# 2     Robb   30  New York
# 3  Danerys   35      Kona

# %%
df_dict.shape
# Out:
# (3, 3)

# %%
df_dict.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, 1 to 3
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      3 non-null      object
#  1   Age       3 non-null      int64
#  2   Location  3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 96.0+ bytes

# %%
df_dict.describe()
# Out:
#         Age
# count   3.0
# mean   30.0
# std     5.0
# min    25.0
# 25%    27.5
# 50%    30.0
# 75%    32.5
# max    35.0

# %%
df_dict["Age"].max()
# Out:
# 35

# %%
df_dict["Age"].min()
# Out:
# 25

# %%
df_dict["Age"].mean()
# Out:
# np.float64(30.0)

# %%
df_dict.drop_duplicates()
# Out:
#       Name  Age  Location
# 1      Jon   25   Seattle
# 2     Robb   30  New York
# 3  Danerys   35      Kona

# %%
df_dict.loc[2]
# Out:
# Name            Robb
# Age               30
# Location    New York
# Name: 2, dtype: object

# %%
df_dict.iloc[1:]
# Out:
#       Name  Age  Location
# 2     Robb   30  New York
# 3  Danerys   35      Kona
